# %%
# pour monter son drive Google Drive local
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/Colab Notebooks
#
# pour une utilisation sur une machine locale changer le chemin ci-dessous et décommenter la ligne
#%cd ./
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks

# %%
# import fastai and fastai text
from fastai import *
from fastai.text import *# import 

import sklearn.feature_extraction.text as sklearn_text# reload all modules before running a python code
# %reload_ext autoreload
# %autoreload 2# plot graphics in the notebook
# %matplotlib inline

# %%
# raw_text = open(filename, 'r', encoding='utf-8').read()

# movie_reviews = (TextList.from_folder('wonderland.txt')
#                          .split_from_df(col=2)
#                          .label_from_df(cols=0))


path = untar_data(URLs.IMDB_SAMPLE)
df = pd.read_csv(path/"texts.csv")

dls = TextList.from_csv(path=path, csv_name='texts.csv', text_col='text', label_col='label', valid_col='is_valid')
dls.show_batch(max_n=3)     


# get train and valid datasets tokenized by fastai, vocab of tokens and classes list
train = movie_reviews.train
valid = movie_reviews.valid
vocab = movie_reviews.vocab
classes = movie_reviews.classes# number of reviews in train and valid
len(train.x), len(valid.x)# size of vocab
len(vocab.itos), len(vocab.stoi)# display vocab
vocab.itos# display the first train review and its label
review = train.x[0]
label = train.y[0]
review, label# display the token list of the train review 0
tokens = review.data; tokens# from a token list, display the corresponding text
' '.join(np.array(movie_reviews.vocab.itos)[tokens])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1034c6b71778> in <module>()
#      11 df = pd.read_csv(path/"texts.csv")
#      12
# ---> 13 dls = TextList.from_csv(path=path, csv_name='texts.csv', text_col='text', label_col='label', valid_col='is_valid')
#      14 dls.show_batch(max_n=3)
#      15
#
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py in from_csv(cls, path, csv_name, cols, delimiter, header, processor, **kwargs)
#     145         """Create an `ItemList` in `path` from the inputs in the `cols` of `path/csv_name`"""
#     146         df = pd.read_csv(Path(path)/csv_name, delimiter=delimiter, header=header)
# --> 147         return cls.from_df(df, path=path, cols=cols, processor=processor, **kwargs)
#     148
#     149     def _relative_item_path(self, i): return self.items[i].relative_to(self.path)
#
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py in from_df(cls, df, path, cols, processor, **kwargs)
#     137         assert not inputs.isna().any().any(), f"You have NaN values in column(s) {cols} of your dataframe, please fix it."
#     138         items = _maybe_squeeze(inputs.values) if len(df) > 1 else (inputs.values[0] if not isinstance(cols, Collection) or len(cols) == 1 else inputs.values)
# --> 139         res = cls(items=items, path=path, inner_df=df, processor=processor, **kwargs)
#     140         return res
#     141
#
# /usr/local/lib/python3.7/dist-packages/fastai/text/data.py in __init__(self, items, vocab, pad_idx, sep, **kwargs)
#     322
#     323     def __init__(self, items:Iterator, vocab:Vocab=None, pad_idx:int=1, sep=' ', **kwargs):
# --> 324         super().__init__(items, **kwargs)
#     325         self.vocab,self.pad_idx,self.sep = vocab,pad_idx,sep
#     326         self.copy_new += ['vocab', 'pad_idx', 'sep']
#
# TypeError: __init__() got an unexpected keyword argument 'text_col'
