# %% [markdown]
# test vous me voyez ?

# %% [markdown]
# test commentaire

# %%
print("coucou")
a = 4;
print(a)
# Out:
# coucou
# 4

# %%
class garde:
  def __init__(self,coordX, coordY):
    self.x=coordX
    self.y=coordY

  def action(self,gardeProche,suspect)
    if(gardeProche[x][y+1])
      move(x,y-1)
    if(gardeProche[x][y+1])
      move(x,y-1)
    if(gardeProche[x][y+1])
      move(x,y-1)
    if(gardeProche[x][y+1])
      move(x,y-1)
    if
    if
    if


  def move(self, x,y)
    self.x=x
    self.y=y  

  
agent = garde(5,5)
# Out:
#   File "<ipython-input-10-9dd7ff7a242c>", line 6
#     def action(delf,gardeProche,suspect)
#                                         ^
# SyntaxError: invalid syntax
